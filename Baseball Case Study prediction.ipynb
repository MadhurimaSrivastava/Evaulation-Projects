# %% [markdown]
# # Baseball Case Study prediction

# %%
#importing required modules to start
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
#collecting data
df= pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %% [markdown]
# Information of the Dataset-
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success.There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# Input and Output features:
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts,Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, and Errors
#
# -- Output: Number of predicted wins (W)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
# replacing the abbrevations with Complete word redability and enhancing interpretation
df.columns = 'Wins,Runs,At_Bats,Hits,Doubles,Triples,Homeruns,Walks,Strikeouts,Stolen_Bases,Runs_Allowed,Earned_Runs,Earned_Run_Average_(ERA),Complete_Game,Shutouts,Saves,Errors'.split(',')

# %%
df
# Out:
#     Wins  Runs  At_Bats  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 0     95   724     5575  1497      300       42       139    383         973
# 1     83   696     5467  1349      277       44       156    439        1264
# 2     81   669     5439  1395      303       29       141    533        1157
# 3     76   622     5533  1381      260       27       136    404        1231
# 4     74   689     5605  1515      289       49       151    455        1259
# 5     93   891     5509  1480      308       17       232    570        1151
# 6     87   764     5567  1397      272       19       212    554        1227
# 7     81   713     5485  1370      246       20       217    418        1331
# 8     80   644     5485  1383      278       32       167    436        1310
# 9     78   748     5640  1495      294       33       161    478        1148
# 10    88   751     5511  1419      279       32       172    503        1233
# 11    86   729     5459  1363      278       26       230    486        1392
# 12    85   661     5417  1331      243       21       176    435        1150
# 13    76   656     5544  1379      262       22       198    478        1336
# 14    68   694     5600  1405      277       46       146    475        1119
# 15   100   647     5484  1386      288       39       137    506        1267
# 16    98   697     5631  1462      292       27       140    461        1322
# 17    97   689     5491  1341      272       30       171    567        1518
# 18    68   655     5480  1378      274       34       145    412        1299
# 19    64   640     5571  1382      257       27       167    496        1255
# 20    90   683     5527  1351      295       17       177    488        1290
# 21    83   703     5428  1363      265       13       177    539        1344
# 22    71   613     5463  1420      236       40       120    375        1150
# 23    67   573     5420  1361      251       18       100    471        1107
# 24    63   626     5529  1374      272       37       130    387        1274
# 25    92   667     5385  1346      263       26       187    563        1258
# 26    84   696     5565  1486      288       39       136    457        1159
# 27    79   720     5649  1494      289       48       154    490        1312
# 28    74   650     5457  1324      260       36       148    426        1327
# 29    68   737     5572  1479      274       49       186    388        1283
#
#     Stolen_Bases  Runs_Allowed  Earned_Runs  Earned_Run_Average_(ERA)  \
# 0            104           641          601                      3.73
# 1             70           700          653                      4.07
# 2             86           640          584                      3.67
# 3             68           701          643                      3.98
# 4             83           803          746                      4.64
# 5             88           670          609                      3.80
# 6             63           698          652                      4.03
# 7             44           693          646                      4.05
# 8             87           642          604                      3.74
# 9             71           753          694                      4.31
# 10           101           733          680                      4.24
# 11           121           618          572                      3.57
# 12            52           675          630                      3.94
# 13            69           726          677                      4.16
# 14            78           729          664                      4.14
# 15            69           525          478                      2.94
# 16            98           596          532                      3.21
# 17            95           608          546                      3.36
# 18            84           737          682                      4.28
# 19           134           754          700                      4.33
# 20            51           613          557                      3.43
# 21            57           635          577                      3.62
# 22           112           678          638                      4.02
# 23            69           760          698                      4.41
# 24            88           809          749                      4.69
# 25            59           595          553                      3.44
# 26            93           627          597                      3.72
# 27           132           713          659                      4.04
# 28            82           731          655                      4.09
# 29            97           844          799                      5.04
#
#     Complete_Game  Shutouts  Saves  Errors
# 0               2         8     56      88
# 1               2        12     45      86
# 2              11        10     38      79
# 3               7         9     37     101
# 4               7        12     35      86
# 5               7        10     34      88
# 6               3         4     48      93
# 7               0        10     43      77
# 8               1        12     60      95
# 9               3        10     40      97
# 10              5         9     45     119
# 11              5        13     39      85
# 12              2        12     46      93
# 13              6        12     45      94
# 14              5        15     28     126
# 15              1        15     62      96
# 16              0        13     54     122
# 17              6        21     48     111
# 18              1         7     40     116
# 19              2         8     35      90
# 20              1        14     50      88
# 21              4        13     41      90
# 22              0        12     35      77
# 23              3        10     44      90
# 24              1         7     35     117
# 25              6        21     47      75
# 26              7        18     41      78
# 27              1        12     44      86
# 28              1         6     41      92
# 29              4         4     36      95

# %%
df.head()
# Out:
#    Wins  Runs  At_Bats  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 0    95   724     5575  1497      300       42       139    383         973
# 1    83   696     5467  1349      277       44       156    439        1264
# 2    81   669     5439  1395      303       29       141    533        1157
# 3    76   622     5533  1381      260       27       136    404        1231
# 4    74   689     5605  1515      289       49       151    455        1259
#
#    Stolen_Bases  Runs_Allowed  Earned_Runs  Earned_Run_Average_(ERA)  \
# 0           104           641          601                      3.73
# 1            70           700          653                      4.07
# 2            86           640          584                      3.67
# 3            68           701          643                      3.98
# 4            83           803          746                      4.64
#
#    Complete_Game  Shutouts  Saves  Errors
# 0              2         8     56      88
# 1              2        12     45      86
# 2             11        10     38      79
# 3              7         9     37     101
# 4              7        12     35      86

# %%
df.shape
# Out:
# (30, 17)

# %%
df.isnull().sum()
# Out:
# Wins                        0
# Runs                        0
# At_Bats                     0
# Hits                        0
# Doubles                     0
# Triples                     0
# Homeruns                    0
# Walks                       0
# Strikeouts                  0
# Stolen_Bases                0
# Runs_Allowed                0
# Earned_Runs                 0
# Earned_Run_Average_(ERA)    0
# Complete_Game               0
# Shutouts                    0
# Saves                       0
# Errors                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Wins                      30 non-null     int64
#  1   Runs                      30 non-null     int64
#  2   At_Bats                   30 non-null     int64
#  3   Hits                      30 non-null     int64
#  4   Doubles                   30 non-null     int64
#  5   Triples                   30 non-null     int64
#  6   Homeruns                  30 non-null     int64
#  7   Walks                     30 non-null     int64
#  8   Strikeouts                30 non-null     int64
#  9   Stolen_Bases              30 non-null     int64
#  10  Runs_Allowed              30 non-null     int64
#  11  Earned_Runs               30 non-null     int64
#  12  Earned_Run_Average_(ERA)  30 non-null     float64
#  13  Complete_Game             30 non-null     int64
#  14  Shutouts                  30 non-null     int64
#  15  Saves                     30 non-null     int64
#  16  Errors                    30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.describe()
# Out:
#              Wins        Runs      At_Bats         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Homeruns       Walks  Strikeouts  Stolen_Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# 25%    23.000000  140.250000  428.250000  1157.50000     69.000000
# 50%    31.000000  158.500000  473.000000  1261.50000     83.500000
# 75%    39.000000  177.000000  501.250000  1311.50000     96.500000
# max    49.000000  232.000000  570.000000  1518.00000    134.000000
#
#        Runs_Allowed  Earned_Runs  Earned_Run_Average_(ERA)  Complete_Game  \
# count     30.000000    30.000000                 30.000000      30.000000
# mean     688.233333   635.833333                  3.956333       3.466667
# std       72.108005    70.140786                  0.454089       2.763473
# min      525.000000   478.000000                  2.940000       0.000000
# 25%      636.250000   587.250000                  3.682500       1.000000
# 50%      695.500000   644.500000                  4.025000       3.000000
# 75%      732.500000   679.250000                  4.220000       5.750000
# max      844.000000   799.000000                  5.040000      11.000000
#
#         Shutouts      Saves      Errors
# count  30.000000  30.000000   30.000000
# mean   11.300000  43.066667   94.333333
# std     4.120177   7.869335   13.958889
# min     4.000000  28.000000   75.000000
# 25%     9.000000  37.250000   86.000000
# 50%    12.000000  42.000000   91.000000
# 75%    13.000000  46.750000   96.750000
# max    21.000000  62.000000  126.000000

# %%
df.corr()
# Out:
#                               Wins      Runs   At_Bats      Hits   Doubles  \
# Wins                      1.000000  0.430751 -0.087947  0.037612  0.427797
# Runs                      0.430751  1.000000  0.319464  0.482856  0.560084
# At_Bats                  -0.087947  0.319464  1.000000  0.739122  0.453370
# Hits                      0.037612  0.482856  0.739122  1.000000  0.566847
# Doubles                   0.427797  0.560084  0.453370  0.566847  1.000000
# Triples                  -0.251118 -0.070072  0.435422  0.478694  0.220490
# Homeruns                  0.307407  0.671283 -0.066983 -0.090855  0.056292
# Walks                     0.484342  0.402452 -0.136414 -0.118281  0.302700
# Strikeouts                0.111850 -0.054726 -0.106022 -0.398830 -0.150752
# Stolen_Bases             -0.157234  0.081367  0.372618  0.413444  0.195027
# Runs_Allowed             -0.812952 -0.041623  0.316010  0.224324 -0.218160
# Earned_Runs              -0.809435 -0.041245  0.309686  0.252489 -0.235531
# Earned_Run_Average_(ERA) -0.819600 -0.049281  0.255551  0.231172 -0.254854
# Complete_Game             0.080533  0.232042 -0.080876  0.147955  0.306675
# Shutouts                  0.471805 -0.103274 -0.197321 -0.145559  0.057998
# Saves                     0.666530 -0.096380 -0.106367 -0.130371  0.171576
# Errors                   -0.089485 -0.023262  0.316743 -0.033173  0.105754
#
#                            Triples  Homeruns     Walks  Strikeouts  \
# Wins                     -0.251118  0.307407  0.484342    0.111850
# Runs                     -0.070072  0.671283  0.402452   -0.054726
# At_Bats                   0.435422 -0.066983 -0.136414   -0.106022
# Hits                      0.478694 -0.090855 -0.118281   -0.398830
# Doubles                   0.220490  0.056292  0.302700   -0.150752
# Triples                   1.000000 -0.430915 -0.454949   -0.141196
# Homeruns                 -0.430915  1.000000  0.425691    0.359923
# Walks                    -0.454949  0.425691  1.000000    0.233652
# Strikeouts               -0.141196  0.359923  0.233652    1.000000
# Stolen_Bases              0.457437 -0.136567 -0.098347    0.030968
# Runs_Allowed              0.314125 -0.103903 -0.416445   -0.129745
# Earned_Runs               0.340225 -0.085922 -0.452663   -0.161612
# Earned_Run_Average_(ERA)  0.330951 -0.090917 -0.459832   -0.180368
# Complete_Game            -0.065898  0.156502  0.462478   -0.093418
# Shutouts                 -0.041396 -0.019119  0.426004    0.237721
# Saves                    -0.142370 -0.028540  0.099445    0.126297
# Errors                    0.126678 -0.207597 -0.075685    0.155133
#
#                           Stolen_Bases  Runs_Allowed  Earned_Runs  \
# Wins                         -0.157234     -0.812952    -0.809435
# Runs                          0.081367     -0.041623    -0.041245
# At_Bats                       0.372618      0.316010     0.309686
# Hits                          0.413444      0.224324     0.252489
# Doubles                       0.195027     -0.218160    -0.235531
# Triples                       0.457437      0.314125     0.340225
# Homeruns                     -0.136567     -0.103903    -0.085922
# Walks                        -0.098347     -0.416445    -0.452663
# Strikeouts                    0.030968     -0.129745    -0.161612
# Stolen_Bases                  1.000000      0.132290     0.143068
# Runs_Allowed                  0.132290      1.000000     0.991018
# Earned_Runs                   0.143068      0.991018     1.000000
# Earned_Run_Average_(ERA)      0.126063      0.986674     0.997248
# Complete_Game                -0.020783     -0.016659    -0.020221
# Shutouts                     -0.106563     -0.636862    -0.630192
# Saves                        -0.183418     -0.616224    -0.589663
# Errors                        0.079149      0.198996     0.136921
#
#                           Earned_Run_Average_(ERA)  Complete_Game  Shutouts  \
# Wins                                     -0.819600       0.080533  0.471805
# Runs                                     -0.049281       0.232042 -0.103274
# At_Bats                                   0.255551      -0.080876 -0.197321
# Hits                                      0.231172       0.147955 -0.145559
# Doubles                                  -0.254854       0.306675  0.057998
# Triples                                   0.330951      -0.065898 -0.041396
# Homeruns                                 -0.090917       0.156502 -0.019119
# Walks                                    -0.459832       0.462478  0.426004
# Strikeouts                               -0.180368      -0.093418  0.237721
# Stolen_Bases                              0.126063      -0.020783 -0.106563
# Runs_Allowed                              0.986674      -0.016659 -0.636862
# Earned_Runs                               0.997248      -0.020221 -0.630192
# Earned_Run_Average_(ERA)                  1.000000      -0.009856 -0.630833
# Complete_Game                            -0.009856       1.000000  0.241676
# Shutouts                                 -0.630833       0.241676  1.000000
# Saves                                    -0.607005      -0.367766  0.221639
# Errors                                    0.113137      -0.140047 -0.115716
#
#                              Saves    Errors
# Wins                      0.666530 -0.089485
# Runs                     -0.096380 -0.023262
# At_Bats                  -0.106367  0.316743
# Hits                     -0.130371 -0.033173
# Doubles                   0.171576  0.105754
# Triples                  -0.142370  0.126678
# Homeruns                 -0.028540 -0.207597
# Walks                     0.099445 -0.075685
# Strikeouts                0.126297  0.155133
# Stolen_Bases             -0.183418  0.079149
# Runs_Allowed             -0.616224  0.198996
# Earned_Runs              -0.589663  0.136921
# Earned_Run_Average_(ERA) -0.607005  0.113137
# Complete_Game            -0.367766 -0.140047
# Shutouts                  0.221639 -0.115716
# Saves                     1.000000 -0.025636
# Errors                   -0.025636  1.000000

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(),annot=True, linewidths=0.5,linecolor="black",fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation:
#
# Note that there are three highly correlated features.
#
# They are as follows:
#
# Runs Allowed
# Earned Runs
# Earned_RunesAverage(AVG)

# %%
sns.pairplot(df, size=2.5)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.hist( bins = 10, figsize = (10,10))
plt.show()

# %% [markdown]
# Note:
#
# We have very less number of samples and there are to many number of features in the data.
# This causes overfitting as the model is prone to have very high variance.
# Either add more data or remove some features to adress overfitting in the data
# In this project we cannot add more data, so maybe we will try to reduce some of the features to address the variance of the model.

# %%
# Let's address the outliers in the dataset
# plotting a box plt for each of the feature seperately:
for col in df:
    plt.figure(figsize=(18,4))
    sns.boxplot(df[col])
    plt.show()

# %%
# addressing outliers using the IOR:
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

df_cleaned = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
for col in df:
    fig = plt.figure(figsize=(18,4))
    
    fig.add_subplot(121)
    sns.boxplot(df[col])
    
    fig.add_subplot(122)
    sns.boxplot(df_cleaned[col])
    plt.show()

# %%
len(df),len(df_cleaned)
# Out:
# (30, 20)

# %% [markdown]
# 1-When we are removing outliers from the data we are ending up removing 1/3 i.e. 0.333 percent of the data.
#
# 2-This is not acceptable, so lets just keep the outliers in the dataset.
#
# i.e., Let's just stick with our ouriginal dataset with outliers

# %% [markdown]
# # Cheking the Skewness

# %%
# let's check the skewness of the features in the dataset:
df.skew()
# Out:
# Wins                        0.047089
# Runs                        1.200786
# At_Bats                     0.183437
# Hits                        0.670254
# Doubles                    -0.230650
# Triples                     0.129502
# Homeruns                    0.516441
# Walks                       0.158498
# Strikeouts                 -0.156065
# Stolen_Bases                0.479893
# Runs_Allowed                0.045734
# Earned_Runs                 0.058710
# Earned_Run_Average_(ERA)    0.053331
# Complete_Game               0.736845
# Shutouts                    0.565790
# Saves                       0.657524
# Errors                      0.890132
# dtype: float64

# %% [markdown]
# while checking the skewness, it has been observed that many columns are above standard thresh hold , have considered 0.5 is the standard threshold, columns Runs, Hits, Earned_Runs, Complete_Game, Shutouts, Saves  and Errors are right skewed data. we will treat the skeweness.

# %%
# we can see that the runs feature has an invalid skew.
# We can address is using the some transformation on the feature
# Let's try log transformation
np.log(df+1).skew()
# Out:
# Wins                       -0.165050
# Runs                        0.744813
# At_Bats                     0.161062
# Hits                        0.628584
# Doubles                    -0.375085
# Triples                    -0.418009
# Homeruns                   -0.009528
# Walks                      -0.051289
# Strikeouts                 -0.540637
# Stolen_Bases               -0.160463
# Runs_Allowed               -0.241950
# Earned_Runs                -0.278793
# Earned_Run_Average_(ERA)   -0.243088
# Complete_Game              -0.325962
# Shutouts                   -0.589640
# Saves                       0.163057
# Errors                      0.632916
# dtype: float64

# %% [markdown]
# 1-Using the log(n+1) transformation the Complete_Game columns become NaN.
#
# 2-Thus we did log(n+1) transformation and it is giving us much acceptable results.

# %%
# Wins vs runs
sns.scatterplot(df.Runs,df.Wins)
# Out:
# <AxesSubplot:xlabel='Runs', ylabel='Wins'>

# %%
sns.scatterplot(df.Doubles,df.Triples)
# Out:
# <AxesSubplot:xlabel='Doubles', ylabel='Triples'>

# %%
# wins vs erros
sns.scatterplot(df.Errors,df.Wins)
# Out:
# <AxesSubplot:xlabel='Errors', ylabel='Wins'>

# %%
# runs alllowed vs runs scores
sns.scatterplot(df.Runs_Allowed,df.Runs)
# Out:
# <AxesSubplot:xlabel='Runs_Allowed', ylabel='Runs'>

# %%
df.columns
# Out:
# Index(['Wins', 'Runs', 'At_Bats', 'Hits', 'Doubles', 'Triples', 'Homeruns',
#        'Walks', 'Strikeouts', 'Stolen_Bases', 'Earned_Run_Average_(ERA)',
#        'Complete_Game', 'Shutouts', 'Saves', 'Errors'],
#       dtype='object')

# %%
plt.bar(df['Errors'], df['Wins'], color = 'green')
plt.title('Wins')
plt.xlabel('Errors')
plt.ylabel('Wins')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.bar(df['Errors'], df['Earned_Run_Average_(ERA)'], color = 'green')
plt.title('Earned_Run_Average_(ERA)')
plt.xlabel('Errors')
plt.ylabel('Earned_Run_Average_(ERA)')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
sns.histplot(x='Errors', data= df, kde=True)
plt.show()
plt.boxplot(df['Errors'])
plt.show()

# %%
sns.histplot(x='Wins', data= df, kde=True)
plt.show()
plt.boxplot(df['Wins'])
plt.show()
print(df.Wins.describe())
# Out:
# count     30.000000
# mean      80.966667
# std       10.453455
# min       63.000000
# 25%       74.000000
# 50%       81.000000
# 75%       87.750000
# max      100.000000
# Name: Wins, dtype: float64

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso
from xgboost import XGBRegressor

# %%
# we can see that the runs feature has an invalid skew.
# We can address is using the some transformation on the feature
# Let's try log transformation
np.log(df+1).skew()
# Out:
# Wins                       -0.165050
# Runs                        0.744813
# At_Bats                     0.161062
# Hits                        0.628584
# Doubles                    -0.375085
# Triples                    -0.418009
# Homeruns                   -0.009528
# Walks                      -0.051289
# Strikeouts                 -0.540637
# Stolen_Bases               -0.160463
# Earned_Run_Average_(ERA)   -0.243088
# Complete_Game              -0.325962
# Shutouts                   -0.589640
# Saves                       0.163057
# Errors                      0.632916
# dtype: float64

# %% [markdown]
# 1-Using the log(n+1) transformation the Complete_Game columns become NaN.
#
# 2-Thus we did log(n+1) transformation and it is giving us much acceptable results.

# %%
# therfore;
df_cleaned = np.log(df + 1)

# %%
# let's do a complete dataset box plot with the transformed data.
plt.figure(figsize=(18,6))
df_cleaned.boxplot()
# Out:
# <AxesSubplot:>

# %%
# we will use the log +1 transformed processed dataframe formodel building.
df_cleaned
# Out:
#         Wins      Runs   At_Bats      Hits   Doubles   Triples  Homeruns  \
# 0   4.564348  6.586172  8.626227  7.311886  5.707110  3.761200  4.941642
# 1   4.430817  6.546785  8.606668  7.207860  5.627621  3.806662  5.056246
# 2   4.406719  6.507278  8.601534  7.241366  5.717028  3.401197  4.955827
# 3   4.343805  6.434547  8.618666  7.231287  5.564520  3.332205  4.919981
# 4   4.317488  6.536692  8.631593  7.323831  5.669881  3.912023  5.023881
# 5   4.543295  6.793466  8.614320  7.300473  5.733341  2.890372  5.451038
# 6   4.477337  6.639876  8.624791  7.242798  5.609472  2.995732  5.361292
# 7   4.406719  6.570883  8.609955  7.223296  5.509388  3.044522  5.384495
# 8   4.394449  6.469250  8.609955  7.232733  5.631212  3.496508  5.123964
# 9   4.369448  6.618739  8.637817  7.310550  5.686975  3.526361  5.087596
# 10  4.488636  6.622736  8.614683  7.258412  5.634790  3.496508  5.153292
# 11  4.465908  6.593045  8.605204  7.218177  5.631212  3.295837  5.442418
# 12  4.454347  6.495266  8.597482  7.194437  5.497168  3.091042  5.176150
# 13  4.343805  6.487684  8.620652  7.229839  5.572154  3.135494  5.293305
# 14  4.234107  6.543912  8.630700  7.248504  5.627621  3.850148  4.990433
# 15  4.615121  6.473891  8.609772  7.234898  5.666427  3.688879  4.927254
# 16  4.595120  6.548219  8.636220  7.288244  5.680173  3.332205  4.948760
# 17  4.584967  6.536692  8.611048  7.201916  5.609472  3.433987  5.147494
# 18  4.234107  6.486161  8.609043  7.229114  5.616771  3.555348  4.983607
# 19  4.174387  6.463029  8.625509  7.232010  5.552960  3.332205  5.123964
# 20  4.510860  6.527958  8.617581  7.209340  5.690359  2.890372  5.181784
# 21  4.430817  6.556778  8.599510  7.218177  5.583496  2.639057  5.181784
# 22  4.276666  6.419995  8.605936  7.259116  5.468060  3.713572  4.795791
# 23  4.219508  6.352629  8.598036  7.216709  5.529429  2.944439  4.615121
# 24  4.158883  6.440947  8.617943  7.226209  5.609472  3.637586  4.875197
# 25  4.532599  6.504288  8.591558  7.205635  5.575949  3.295837  5.236442
# 26  4.442651  6.546785  8.624432  7.304516  5.666427  3.688879  4.919981
# 27  4.382027  6.580639  8.639411  7.309881  5.669881  3.891820  5.043425
# 28  4.317488  6.478510  8.604838  7.189168  5.564520  3.610918  5.003946
# 29  4.234107  6.603944  8.625689  7.299797  5.616771  3.912023  5.231109
#
#        Walks  Strikeouts  Stolen_Bases  Runs_Allowed  Earned_Runs  \
# 0   5.950643    6.881411      4.653960      6.464588     6.400257
# 1   6.086775    7.142827      4.262680      6.552508     6.483107
# 2   6.280396    7.054450      4.465908      6.463029     6.371612
# 3   6.003887    7.116394      4.234107      6.553933     6.467699
# 4   6.122493    7.138867      4.430817      6.689599     6.616065
# 5   6.347389    7.049255      4.488636      6.508769     6.413459
# 6   6.318968    7.113142      4.158883      6.549651     6.481577
# 7   6.037871    7.194437      3.806662      6.542472     6.472346
# 8   6.079933    7.178545      4.477337      6.466145     6.405228
# 9   6.171701    7.046647      4.276666      6.625392     6.543912
# 10  6.222576    7.118016      4.624973      6.598509     6.523562
# 11  6.188264    7.239215      4.804021      6.428105     6.350886
# 12  6.077642    7.048386      3.970292      6.516193     6.447306
# 13  6.171701    7.198184      4.248495      6.588926     6.519147
# 14  6.165418    7.021084      4.369448      6.593045     6.499787
# 15  6.228511    7.145196      4.248495      6.265301     6.171701
# 16  6.135565    7.187657      4.595120      6.391917     6.278521
# 17  6.342121    7.325808      4.564348      6.411818     6.304449
# 18  6.023448    7.170120      4.442651      6.603944     6.526495
# 19  6.208590    7.135687      4.905275      6.626718     6.552508
# 20  6.192362    7.163172      3.951244      6.419995     6.324359
# 21  6.291569    7.204149      4.060443      6.455199     6.359574
# 22  5.929589    7.048386      4.727388      6.520621     6.459904
# 23  6.156979    7.010312      4.248495      6.634633     6.549651
# 24  5.961005    7.150701      4.488636      6.697034     6.620073
# 25  6.335054    7.138073      4.094345      6.390241     6.317165
# 26  6.126869    7.056175      4.543295      6.442540     6.393591
# 27  6.196444    7.180070      4.890349      6.570883     6.492240
# 28  6.056784    7.191429      4.418841      6.595781     6.486161
# 29  5.963579    7.157735      4.584967      6.739337     6.684612
#
#     Earned_Run_Average_(ERA)  Complete_Game  Shutouts     Saves    Errors
# 0                   1.553925       1.098612  2.197225  4.043051  4.488636
# 1                   1.623341       1.098612  2.564949  3.828641  4.465908
# 2                   1.541159       2.484907  2.397895  3.663562  4.382027
# 3                   1.605430       2.079442  2.302585  3.637586  4.624973
# 4                   1.729884       2.079442  2.564949  3.583519  4.465908
# 5                   1.568616       2.079442  2.397895  3.555348  4.488636
# 6                   1.615420       1.386294  1.609438  3.891820  4.543295
# 7                   1.619388       0.000000  2.397895  3.784190  4.356709
# 8                   1.556037       0.693147  2.564949  4.110874  4.564348
# 9                   1.669592       1.386294  2.397895  3.713572  4.584967
# 10                  1.656321       1.791759  2.302585  3.828641  4.787492
# 11                  1.519513       1.791759  2.639057  3.688879  4.454347
# 12                  1.597365       1.098612  2.564949  3.850148  4.543295
# 13                  1.640937       1.945910  2.564949  3.828641  4.553877
# 14                  1.637053       1.791759  2.772589  3.367296  4.844187
# 15                  1.371181       0.693147  2.772589  4.143135  4.574711
# 16                  1.437463       0.000000  2.639057  4.007333  4.812184
# 17                  1.472472       1.945910  3.091042  3.891820  4.718499
# 18                  1.663926       0.693147  2.079442  3.713572  4.762174
# 19                  1.673351       1.098612  2.197225  3.583519  4.510860
# 20                  1.488400       0.693147  2.708050  3.931826  4.488636
# 21                  1.530395       1.609438  2.639057  3.737670  4.510860
# 22                  1.613430       0.000000  2.564949  3.583519  4.356709
# 23                  1.688249       1.386294  2.397895  3.806662  4.510860
# 24                  1.738710       0.693147  2.079442  3.583519  4.770685
# 25                  1.490654       1.945910  3.091042  3.871201  4.330733
# 26                  1.551809       2.079442  2.944439  3.737670  4.369448
# 27                  1.617406       0.693147  2.564949  3.806662  4.465908
# 28                  1.627278       0.693147  1.945910  3.737670  4.532599
# 29                  1.798404       1.609438  1.609438  3.610918  4.564348

# %%
# let's drop the near perfectly correlated feaatures
df_cleaned.drop(['Runs_Allowed','Earned_Runs'],1,inplace=True)

# %%
# Split the features and the target variables into X and y respectively.
X = df_cleaned.drop('Wins',1)
y = df_cleaned['Wins']

# %%
# check the shapes
X.shape,y.shape
# Out:
# ((30, 14), (30,))

# %%
# train _test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.22,random_state = 42)

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((23, 14), (23,), (7, 14), (7,))

# %%
# applying standard scaling to the dataframe
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
def train_n_ret_scores(model):
    model.fit(X_train,y_train)
    
    y_preds = model.predict(X_test)
    print('MSE:',mean_squared_error(y_test,y_preds))
    print('R2_Score',r2_score(y_test,y_preds))

# %%
# try1: Linear Regression
train_n_ret_scores(LinearRegression())
# Out:
# MSE: 0.002243332452818958
# R2_Score 0.8693332554372704

# %%
# try2: Ridge Regression
train_n_ret_scores(Ridge(alpha=0.001))
# Out:
# MSE: 0.0022445413188833204
# R2_Score 0.8692628429609367

# %%
# try3: Lasso Regression
train_n_ret_scores(Lasso(alpha=0.00003))
# Out:
# MSE: 0.002260698472981757
# R2_Score 0.8683217418215188

# %%
# ElasticNet
train_n_ret_scores(ElasticNet(alpha=0.0001))
# Out:
# MSE: 0.0022694205406136466
# R2_Score 0.8678137100396566

# %%
# try4: SVR
train_n_ret_scores(SVR(kernel='linear',C=10,gamma=0.001))
# Out:
# MSE: 0.005901364125097321
# R2_Score 0.6562649295530079

# %%
# try5: Decision Trees
train_n_ret_scores(DecisionTreeRegressor(criterion='mse'))
# Out:
# MSE: 0.008020697294464233
# R2_Score 0.5328207358326333

# %%
# try6: Random Forest
train_n_ret_scores(RandomForestRegressor(n_estimators=500))
# Out:
# MSE: 0.007441519052587552
# R2_Score 0.5665559654427131

# %%
# try7: Gradient Boosting
train_n_ret_scores(GradientBoostingRegressor())
# Out:
# MSE: 0.005345415387891327
# R2_Score 0.6886471168401324

# %%
# try3: Adaboost
train_n_ret_scores(AdaBoostRegressor(base_estimator=LinearRegression()))
# Out:
# MSE: 0.0028015889727863786
# R2_Score 0.8368166473868682

# %%
#let's create the models dataframe
models = [LinearRegression(),Ridge(alpha=0.001),Lasso(alpha=0.0003),ElasticNet(alpha=0.0001),SVR(kernel='linear'),DecisionTreeRegressor(),RandomForestRegressor(),GradientBoostingRegressor(),AdaBoostRegressor(base_estimator=LinearRegression())]
model_names = 'Linear Ridge Lasso ElasticNet SVR Descision_Tree Random_Forest Gradient_Boost Ada_Boost'.split()
models_df = pd.DataFrame(columns=['Model','MSE','R2','meanCV'])
for model,model_names in zip(models,model_names):
    print(model)
    
    model.fit(X_train,y_train)
    
    y_preds = model.predict(X_test)
    
    mse = mean_squared_error(y_test,y_preds)
    r2 = r2_score(y_test,y_preds)
    avgCV = np.mean(cross_val_score(model,X,y,scoring='r2'))
    
    
    models_df = models_df.append({'Model':model_names,'MSE':mse,'R2':r2,'meanCV':avgCV},ignore_index=True)
# Out:
# LinearRegression()
# Ridge(alpha=0.001)
# Lasso(alpha=0.0003)
# ElasticNet(alpha=0.0001)
# SVR(kernel='linear')
# DecisionTreeRegressor()
# RandomForestRegressor()
# GradientBoostingRegressor()
# AdaBoostRegressor(base_estimator=LinearRegression())

# %%
models_df
# Out:
#             Model       MSE        R2    meanCV
# 0          Linear  0.002243  0.869333  0.497937
# 1           Ridge  0.002245  0.869263  0.560001
# 2           Lasso  0.002373  0.861766  0.611066
# 3      ElasticNet  0.002269  0.867814  0.589938
# 4             SVR  0.005901  0.656265 -0.234918
# 5  Descision_Tree  0.010061  0.413974 -1.953618
# 6   Random_Forest  0.007440  0.566641 -0.660530
# 7  Gradient_Boost  0.004585  0.732956 -1.264596
# 8       Ada_Boost  0.002205  0.871549  0.649469

# %% [markdown]
# The Lasso model is outperforming Linear by around 1 percent
#
# We can see that the Ensemble Methods are doing bad on this model as one of the main reason for that is Very Less Data and Too Many Features wrt to the number of samples

# %%
# Best model

best_model = Lasso(alpha=0.001)
best_model.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.001)

# %%
train_n_ret_scores(Lasso(alpha=0.0001,))
# Out:
# MSE: 0.0022856579859010227
# R2_Score 0.8668679322022921

# %%
np.mean(cross_val_score(best_model,X,y))
# Out:
# 0.5791466844384766

# %% [markdown]
# We are getting around 60 percent of accuracy on cross_validation with 'r2' metric
